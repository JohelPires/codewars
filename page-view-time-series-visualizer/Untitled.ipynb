# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
# Import data (Make sure to parse dates. Consider setting index column to 'date'.)
df = pd.read_csv(
    '/home/johel/Documentos/codewars_fns/codewars/page-view-time-series-visualizer/fcc-forum-pageviews.csv', index_col=0, parse_dates=True)

df
# Out:
#              value
# date
# 2016-05-09    1201
# 2016-05-10    2329
# 2016-05-11    1716
# 2016-05-12   10539
# 2016-05-13    6933
# ...            ...
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-02  220144
# 2019-12-03  158549
#
# [1304 rows x 1 columns]

# %%
q = df.value.quantile(0.025)
upperq = df.value.quantile(0.975)
df = df[(df.value > q) & (df.value < upperq)]

# %% [markdown]
# ## Draw Line Plot

# %%
# df.plot()

# cleandf.plot(fmt='r', title='Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
plt.figure(figsize=(15, 5))
plt.plot(df, 'r', linewidth=1)

plt.title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
plt.xlabel("Dates")
plt.ylabel("Page Views")

plt.show()

# %% [markdown]
# ## Draw Bar Plot

# %%
df.groupby([df.index.year, df.index.month]).value.mean().plot.bar(legend=True)
plt.legend(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])

# %%
df['month'] = df.index.month
df['year'] = df.index.year
dfbar = df.groupby(['year', 'month']).value.mean().plot.bar(legend=True)
plt.legend(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])

# dfbar.plot(kind='bar')
# Out:
# /tmp/ipykernel_4918/665496348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.index.month
# /tmp/ipykernel_4918/665496348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df.index.year

# %%
# cleandf.groupby([cleandf.index.year, cleandf.index.month]).sum().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [140], in <cell line: 2>()
#       1 # cleandf.groupby([cleandf.index.year, cleandf.index.month]).sum().plot(kind='bar')
# ----> 2 sns.barplot(df2016.groupby(by=[df2016.index.month]))
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:2753, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2750 if estimator is len:
#    2751     estimator = "size"
# -> 2753 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2754                       estimator, errorbar, n_boot, units, seed,
#    2755                       orient, color, palette, saturation,
#    2756                       width, errcolor, errwidth, capsize, dodge)
#    2758 if ax is None:
# ...

# %%
cleandf.value
# Out:
# date
# 2016-05-19     19736
# 2016-05-26     18060
# 2016-05-27     19997
# 2016-05-28     19044
# 2016-05-29     20325
#                ...
# 2019-11-24    138875
# 2019-11-29    171584
# 2019-11-30    141161
# 2019-12-01    142918
# 2019-12-03    158549
# Name: value, Length: 1238, dtype: int64

# %%
# Clean data
df = None


def draw_line_plot():
    # Draw line plot

    # Save image and return fig (don't change this part)
    fig.savefig('line_plot.png')
    return fig


def draw_bar_plot():
    # Copy and modify data for monthly bar plot
    df_bar = None

    # Draw bar plot

    # Save image and return fig (don't change this part)
    fig.savefig('bar_plot.png')
    return fig


def draw_box_plot():
    # Prepare data for box plots (this part is done!)
    df_box = df.copy()
    df_box.reset_index(inplace=True)
    df_box['year'] = [d.year for d in df_box.date]
    df_box['month'] = [d.strftime('%b') for d in df_box.date]

    # Draw box plots (using Seaborn)

    # Save image and return fig (don't change this part)
    fig.savefig('box_plot.png')
    return fig
