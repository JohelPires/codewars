# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/johel/Documentos/codewars_fns/codewars/Piece_Dim.csv', index_col='Item_No')

# %%
df.head()
# Out:
#          Length  Width  Height Operator
# Item_No
# Item-1   102.67  49.53   19.69     Op-1
# Item-2   102.50  51.42   19.63     Op-1
# Item-3    95.37  52.25   21.51     Op-1
# Item-4    94.77  49.24   18.60     Op-1
# Item-5   104.26  47.90   19.46     Op-1

# %%
df.loc[['Item-1', 'Item-5']]
# Out:
#          Length  Width  Height Operator
# Item_No
# Item-1   102.67  49.53   19.69     Op-1
# Item-5   104.26  47.90   19.46     Op-1

# %%
df.iloc[0:5][['Width', 'Height']]
# Out:
#          Width  Height
# Item_No
# Item-1   49.53   19.69
# Item-2   51.42   19.63
# Item-3   52.25   21.51
# Item-4   49.24   18.60
# Item-5   47.90   19.46

# %%
df[df['Operator'] == 'Op-1'].describe()
# Out:
#            Length      Width     Height
# count   25.000000  25.000000  25.000000
# mean    99.547200  49.301200  20.024800
# std      5.147417   2.955796   0.823514
# min     89.820000  44.460000  18.600000
# 25%     95.510000  47.900000  19.510000
# 50%     98.730000  49.240000  19.940000
# 75%    104.260000  50.810000  20.360000
# max    108.450000  55.760000  22.310000

# %%
plt.hist(df['Length'], bins=15, color='orange');
plt.xlabel('Length in mm')
plt.ylabel('Count')
plt.title('Histogram of piece length')
plt.show()

# %%
plt.boxplot(df['Length'])
plt.show()

# %%
op1 = df[df['Operator'] == 'Op-1']
op2 = df[df['Operator'] == 'Op-2']
b

# %%
plt.plot(df['Length'])
m = df['Length'].mean()
std = df['Length'].std()
plt.axhline(m, color='orange')
plt.axhline(m+std, color='red', linestyle='--')
plt.axhline(m-std, color='red', linestyle='--')
plt.xlabel('Item')
plt.ylabel('Length in mm')
plt.title('Length of items')
plt.show()

# %%
plt.scatter(x=df['Length'], y=df['Width'])
# plt.xlabel('Operator')
# plt.ylabel('Length in mm')
plt.title('Scatter')
plt.show()
