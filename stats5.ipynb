# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid', palette='muted')

# %%
a = np.random.normal(100, 5, 1000)
b = np.random.normal(80, 5, 1000)

# %%
ab = np.append(a,b)
np.random.shuffle(ab)

# %%
sns.displot(data=ab);

# %%
ab4 = ab.reshape(500, 4)

# %%
ab4
# Out:
# array([[ 83.50875915, 102.46046572, 103.75212198, 103.75057723],
#        [ 81.3295713 ,  94.49326234,  82.78938007,  72.1242298 ],
#        [107.04092264,  97.69245757,  72.49837891,  93.81650254],
#        ...,
#        [103.27925935,  98.89673318,  99.40762335, 102.26421278],
#        [ 87.33196529,  92.57975913,  83.22029777, 105.73628458],
#        [ 97.03828302, 107.3157431 ,  77.89223992,  90.48438131]])

# %%
mean4 = ab4.mean(axis=1)

# %%
sns.displot(mean4)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 sns.relplot(kind='bar', x=['ab', 'mean4'], y=[ab, mean4])
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:844, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     842 else:
#     843     err = f"Plot kind {kind} not recognized"
# --> 844     raise ValueError(err)
#     846 # Check for attempt to plot onto specific axes and warn
#     847 if "ax" in kwargs:
#
# ValueError: Plot kind bar not recognized
